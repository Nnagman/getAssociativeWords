# %%
import xml.etree.ElementTree as elemTree
import re

tree = elemTree.parse('./bizinfodata.xml')
root = tree.find('./database')
count = 0
wordsList = []

#지원사업 공고문에서 띄워쓰기로 문장 구분하기
#p = re.compile('[가-힣]+')
p = re.compile('[가-힣]{2,}')


for table in root:
    wordsList.insert(count, p.findall(table[1].text))
    wordsList[count].extend(p.findall(table[2].text))
    count += 1
    
print(wordsList[0])

keywords= ['청년', '시스템', '인재', '문화', '혁신', '동반성장', 
           '맞춤', '생산', '예비', '환경기술', '마케팅', '품질', 
           '경쟁력', '공유', '발명', '시설', '개선', '자금', '특허', 
           '박람회', '서비스', '연구', '홍보', '아이디어', '게임', 
           '관내', '기금', '골목', '영세', '체험', '채용', '안정', 
           '공장', '투자', '스타트업', '제조', '기술', '수출', 
           '신용카드', '교육', '프린팅', '융합', '훈련', '보험료', 
           '선도', '장비', '클러스터', '일자리', '경제', '콘텐츠', 
           '홈쇼핑', '융자', '점포', '신기술', '인건비', '브랜드', 
           '소재', '산업', '식품', '개발', '컨설팅', '가맹', '상점', 
           '고용', '육성', '인증', '제품', '협력', '자동차', '패키지', 
           '바이오', '모델', '해외', '부품', '시니어', '로봇', '시장', 
           '에너지', '입지', '신규']

matchKeyword = []
count = 0

#공고문에서 키워드만 추출하기
for words in wordsList:
    tempWords = []
    for keyword in keywords:
        if(keyword in words):
            tempWords.append(keyword)
    matchKeyword.insert(count, tempWords)
    count += 1
# Out:
# ['마이크로의료로봇', '실증지원', '실증지원사업', '수혜기업', '공고', '산업화', '초기단계의', '국내', '마이크로의료로봇', '산업', '경쟁력', '강화를', '위하여', '마이크로의료로봇', '제품화', '성장기반을', '지원해', '드리는', '사업입니다', '마이크로', '의료기기', '로봇산업분야', '관련', '중소', '중견기업', '천원', '지원']

# %%
from collections import Counter
import collections

wordsMatchKeywords = []
count = 0

#키워드별 단어 추출
for keyword in keywords:
    tempWords = []
    for words in wordsList:
        if(keyword in words):
            tempWords.extend(words)
    wordsMatchKeywords.insert(count, tempWords)
    count += 1

count = 0

#단어 빈도수 추출
for wordsMatchKeyword in wordsMatchKeywords:
    wordsMatchKeywords[count] = Counter(wordsMatchKeyword)
    #낮은 빈도수 단어 제외
    #wordsMatchKeywords[count] = dict(wordsMatchKeywords[count].most_common(50))
    count += 1

#비슷한 단어들 빈도수 추가작업
for wordsMatchKeyword in wordsMatchKeywords:
    for key in wordsMatchKeyword:
        for item in wordsMatchKeyword:
            if(key in item):
                wordsMatchKeyword[key] += 1

count = 0

for keyword in keywords:
    keywordWords[keyword] = wordsMatchKeywords[count]
    count += 1

print(keywordWords)
# Out:
# {'청년': Counter({'청년': 148, '지원': 80, '기업': 66, '지역': 55, '사업입니다': 54, '드리는': 53, '사업': 52, '공고': 50, '창업': 50, '지원해': 49, '모집': 41, '만원': 33, '채용': 31, '일자리': 29, '최대': 27, '위해': 26, '소재': 24, '지원사업': 21, '등을': 21, '위하여': 21, '고용': 21, '중소기업': 20, '전남': 19, '인건비': 18, '신규': 17, '창출': 17, '창업자': 16, '중소': 16, '이상': 16, '우수': 16, '추가': 15, '대상으로': 15, '교육': 14, '청년일자리': 14, '대구': 14, '인력': 14, '부산': 14, '이하': 13, '도내': 13, '사업장': 13, '참여기업': 12, '인당': 12, '개발': 11, '프로젝트': 11, '예비': 11, '소상공인': 11, '성장': 11, '산업': 11, '법인': 11, '활성화': 11, '창업기업': 11, '아이템': 11, '경북': 11, '중견기업': 10, '근로자': 10, '서울시': 10, '기업을': 10, '경기': 10, '일자리를': 10, '이내': 10, '벤처': 10, '인재': 10, '사업화': 10, '자금': 10, '시행': 9, '서울': 9, '분야': 9, '참여': 9, '마을기업': 9, '기업의': 9, '울산': 9, '충북': 9, '한도': 9, '소기업': 9, '홍보': 9, '매칭': 9, '강화': 9, '제주': 9, '진출': 9, '시장': 9, '휴게소': 9, '활성화를': 8, '인건비를': 8, '년간': 8, '창출을': 8, '관련': 8, '있는': 8, '백만원': 8, '경남': 8, '경제': 8, '사회': 8, '보험': 8, '대상': 8, '글로벌': 8, '고속도로': 8, '가능한': 8, '보유': 8, '제공': 8, '참가': 8, '통한': 7, '지역경제': 7, '청년에게': 7, '경쟁력': 7, '해소와': 7, '마케팅': 7, '천원': 7, '기업당': 7, '예비창업자': 7, '발굴': 7, '청년의': 7, '목포시': 7, '부담금': 7, '단체': 7, '임금': 7, '대전': 7, '광주': 7, '청년창업': 7, '서비스': 7, '정착': 7, '도모하기': 6, '또는': 6, '천만원': 6, '산업단지': 6, '교통비': 6, '입주': 6, '중소기업에': 6, '프로그램': 6, '상시근로자': 6, '지역주도형': 6, '일자리사업': 6, '청년일자리사업': 6, '경기도': 6, '사회적': 6, '참여자': 6, '지원금': 6, '창업가': 6, '제공하고': 6, '기업에': 6, '개월': 6, '스타트업': 6, '중인': 6, '연구개발': 6, '전략': 6, '발전': 6, '역량': 6, '도시청년': 5, '정착을': 5, '컨설팅': 5, '정규직으로': 5, '근속': 5, '근무하는': 5, '매월': 5, '만원씩': 5, '업체': 5, '원을': 5, '기준': 5, '정규직': 5, '강화를': 5, '소셜벤처': 5, '참가기업': 5, '시상': 5, '우수기업': 5, '안정적': 5, '적합한': 5, '인재와': 5, '구인': 5, '채용시': 5, '등록': 5, '장년': 5, '경상남도': 5, '중견': 5, '관내': 5, '기반을': 5, '인턴': 5, '이하의': 5, '남도': 5, '전통시장': 5, '창업점포': 5, '집합점포': 5, '창업교육': 5, '보증금': 5, '소셜': 5, '특화': 5, '창업자를': 5, '맞춤형': 5, '전문가': 5, '해외진출': 5, '코칭': 5, '현지': 5, '참가비': 5, '항공료': 5, '숙박료': 5, '업력': 5, '한국도로공사': 5, '공모': 5, '공간': 5, '희망하는': 5, '연장': 5, '상생': 5, '추가고용': 4, '장려금': 4, '청년들의': 4, '성장촉진': 4, '관한': 4, '재공고': 4, '비용': 4, '외식업': 4, '창업지원': 4, '화성시': 4, '협동조합': 4, '부천시': 4, '부천': 4, '중소기업의': 4, '인력난': 4, '지원금을': 4, '충남': 4, '당진시': 4, '위한': 4, '해운선사': 4, '국내': 4, '장려하고': 4, '성동구': 4, '조성을': 4, '소재의': 4, '설립': 4, '청년채용': 4, '선정': 4, '푸드트레일러': 4, '푸드트럭': 4, '임대': 4, '강원': 4, '강원도': 4, '전북': 4, '업체당': 4, '경험': 4, '주도형': 4, '연구개발서비스': 4, '대구시': 4, '고용친화대표기업': 4, '채용지원': 4, '지정': 4, '일하는': 4, '제주특별자치도': 4, '조례': 4, '기본': 4, '마을로': 4, '유입과': 4, '청년인건비': 4, '대보험': 4, '마을에': 4, '강서구': 4, '환경': 4, '개선': 4, '입점': 4, '청년고용특별자금': 4, '고용안정지원자금': 4, '임산업분야': 4, '비즈니스': 4, '모델': 4, '아이템을': 4, '사업비': 4, '교육비': 4, '선도인력': 4, '출신': 4, '보유한': 4, '창직': 4, '양성사업': 4, '사업비를': 4, '회사': 4, '휴게소에': 4, '도입': 4, '발굴하여': 4, '창업공간': 4, '한국도로공사가': 4, '관리하고': 4, '매장에서': 4, '창업이': 4, '기여하기': 4, '실업': 4, '의성군': 4, '창업사업화': 4, '경영': 4, '신규채용': 4, '곡성군': 3, '조성': 3, '구조': 3, '활동비': 3, '사업화자금': 3, '재개': 3, '양질의': 3, '창출하기': 3, '청년을': 3, '고용한': 3, '지원하는': 3, '신청': 3, '접수를': 3, '재개합니다': 3, '명당': 3, '안내': 3, '상품': 3, '중견기업에': 3, '장기근속을': 3, '정부가': 3, '공제금을': 3, '적립하여': 3, '중소기업기본법': 3, '따른': 3, '교통여건이': 3, '열악한': 3, '근로자에게': 3, '교통비를': 3, '산업단지에': 3, '입주한': 3, '인재를': 3, '원하는': 3, '제공해': 3, '중구': 3, '가진': 3, '임금의': 3, '일부를': 3, '인건비의': 3, '사회적기업': 3, '기본급의': 3, '창출과': 3, '자격': 3, '두고': 3, '유통채널': 3, '도모하고': 3, '채용을': 3, '고용장려금': 3, '혁신전문인력': 3, '대구광역시': 3, '역외유출': 3, '서울숲': 3, '혁신경연대회': 3, '사업개발비': 3, '추가모집': 3, '충청북도': 3, '촉진을': 3, '창업을': 3, '예정': 3, '청년근로자를': 3, '청년인재': 3, '임금을': 3, '성장촉진지역': 3, '소상공인의': 3, '차산업': 3, '신산업': 3, '분야의': 3, '유망': 3, '벤처기업': 3, '제작': 3, '참가자': 3, '정부': 3, '연계': 3, '연구개발서비스업': 3, '기업부설연구소': 3, '연간': 3, '성공사다리': 3, '경남도내': 3, '성공': 3, '교육을': 3, '창업특별자금': 3, '취업지원': 3, '참가를': 3, '마을사업장을': 3, '마을사업장': 3, '문화': 3, '청년활동가': 3, '직무역량': 3, '사업장을': 3, '유입': 3, '근무환경': 3, '고용노동부': 3, '받은': 3, '푸드쇼': 3, '대회': 3, '상인': 3, '은평구': 3, '도전을': 3, '입점과': 3, '접수': 3, '우수한': 3, '포레스트': 3, '소셜챌린저': 3, '사회적경제': 3, '초기창 ...
